# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
img = cv.imread('/content/nature.jpg', cv.IMREAD_GRAYSCALE)
equ = cv.equalizeHist(img)
res = np.hstack((img, equ))
cv.imwrite('res.png', res)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=3200x665>

# %%
import numpy as np
import cv2 as cv
img=cv.imread('/content/nature.jpg',cv.IMREAD_GRAYSCALE)
clahe=cv.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))
cl1=clahe.apply(img)
cv.imwrite('clahe_2.jpg',cl1)
cv2_imshow(cl1)
# Out:
# <PIL.Image.Image image mode=L size=1600x665>
