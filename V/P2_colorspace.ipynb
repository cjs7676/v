# %%
import cv2
from google.colab.patches import cv2
from google.colab.patches import cv2_imshow
path = r'/content/zidane.jpg'

# %%
src = cv2.imread(path)

# %%
window_name = 'Image'

# %%
image = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1280x720>
# -1
